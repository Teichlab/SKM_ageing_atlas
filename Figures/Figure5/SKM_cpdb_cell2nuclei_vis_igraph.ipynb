# %% [markdown]
# ## Visualisation of broad cell type interactions

# %% [markdown]
# _15 February 2022_

# %% [markdown]
# ## Importing

# %% [markdown]
# ### Modules

# %%
import numpy as np
import scipy as sp
import scanpy as sc
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
import seaborn as sb
import re
import os
from numpy import asarray as ar
from collections import Counter

#sklearn <- machine learning
#statsmodels

sc.settings.verbosity = 1
sc.logging.print_version_and_date()
# %load_ext autoreload
# %autoreload 2
# Out:
# Running Scanpy 1.7.2, on 2022-02-16 13:31.

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all" # to show output from all the lines in a cells

# %%
pd.set_option('display.max_column',None) # display all the columns in pandas

# %%
pd.options.display.max_rows = 100

# %%
from datetime import date
today = str(date.today())

# %%
# %cd /nfs/team205/vk8/scripts/cpdb
# Out:
# /nfs/team205/vk8/scripts/cpdb

# %%
sc.settings.set_figure_params(dpi = 300, color_map = 'RdPu', dpi_save = 200, vector_friendly = True, format = 'pdf')

# %% [markdown]
# ## Load cpdb results

# %%
adata = sc.read("/nfs/team205/vk8/processed_data/muscle/data_v3/SKM_cells2nuclei_combined_no_int_2022-01-27_v2.h5ad")

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata

# %%
ctypes = adata.obs['annotation_level0'].unique().tolist()
n_ctypes = len(ctypes)
n_genes = adata.var.shape[0]

# %%
n_ctypes
n_genes
# Out:
# 39
# 33694

# %%
de_lmm = pd.read_csv("/nfs/team205/vk8/scripts/de_lmm_natsuhiko/results_all/de_celltype_Age_interaction_scells2snuclei_broad.txt", \
                        sep = "\t"
)

# %%
len(set(adata.var['GeneID']).difference(set(de_lmm['ENSEMBL'])))
# Out:
# 18224

# %%
len(set(de_lmm['ENSEMBL']).difference(set(adata.var['GeneID'])))
# Out:
# 0

# %%
df_ctype_broad_exprs = pd.DataFrame({"ENSEMBL": np.tile(adata.var['GeneID'], reps = n_ctypes), \
                                    "celltype":np.repeat(ctypes, repeats = n_genes)})

# %%
for i in ctypes:
    df_ctype_broad_exprs.loc [df_ctype_broad_exprs ['celltype'] == i, 'mean_young'] = \
    adata[(adata.obs['annotation_level0'] == i) & (adata.obs['Age_bin'] == 'young'),:].X.mean(0).T
    df_ctype_broad_exprs.loc [df_ctype_broad_exprs ['celltype'] == i, 'mean_aged'] = \
    adata[(adata.obs['annotation_level0'] == i) & (adata.obs['Age_bin'] == 'old'),:].X.mean(0).T

# %%
2**0.15
# Out:
# 1.109569472067845

# %%
de_results = pd.read_csv("/nfs/team205/vk8/scripts/de_lmm_natsuhiko/results_all/de_celltype_Age_interaction_scells2snuclei_broad.txt", \
                        sep = "\t"
)
de_results['log2fc'] = de_results['beta_old']-de_results['beta_young']
de_results['sign'] = (de_results['ltsr']>0.9) & (de_results['flag5']==True)
de_results['REGULATION'] = de_results.apply(lambda x: "up" if ((x['sign'] == True) & (x['log2fc'] > 0.15)) else
                                            "dw" if ((x['sign'] == True) & (x['log2fc'] < (-0.15))) else
                                            "none", axis = 1)

# %%
de_results = de_results.merge(df_ctype_broad_exprs, how = 'outer', on = ['celltype', 'ENSEMBL'])

# %%
de_results[(de_results['celltype'] == 'MuSC') & (de_results['gene'] == 'CCL2')]
# Out:
#       celltype  gene          ENSEMBL  ltsr  beta_old  beta_young flag5  \
# 12677     MuSC  CCL2  ENSG00000108691   1.0  0.217809   -0.179205  True
#
#          log2fc  sign REGULATION  mean_young  mean_aged
# 12677  0.397014  True         up     0.47246   1.047496

# %%
de_results['celltype'].unique()
# Out:
# array(['MuSC', 'CapEC', 'ArtEC', 'VenEC', 'Mural', 'Lymphatic',
#        'Pericyte', 'SMC', 'FB', 'NerveFB', 'Tenocyte', 'nmSchwann_cell',
#        'mSchwann_cell', 'B-plasma', 'B-cell', 'T-cell', 'RBC', 'NK-cell',
#        'Eosinophil', 'Neutrophil', 'Macrophage', 'cDC2', 'Monocyte',
#        'cDC1', 'Mast_cell', 'pDC', 'MF_typeI(fg)', 'MF_type-HOOK2+',
#        'MF_typeII(fg)', 'MF_type-MYH8+', 'Mesothelium', 'MF_typeI',
#        'MF_typeII', 'MF_type-SORBS2', 'MF_typeI(cytoplasmic)', 'MTJ',
#        'MF_typeII(cytoplasmic)', 'NMJ', 'Adipocyte'], dtype=object)

# %%
de_results['celltype_group'] = de_results['celltype'].apply(lambda x: 'Myofiber' if x in ['MF_typeI(fg)', \
'MF_type-HOOK2+','MF_typeII(fg)', 'MF_type-MYH8+', 'MF_typeI', 'MF_typeII', 'MF_type-SORBS2', 'MF_typeI(cytoplasmic)', \
  'MTJ','MF_typeII(cytoplasmic)', 'NMJ']  else
    'Immune' if x in ['B-plasma', 'B-cell', 'T-cell', 'NK-cell', 'Eosinophil', 'Neutrophil', 'Macrophage', 'cDC2', \
                               'Monocyte','cDC1', 'Mast_cell', 'pDC', 'RBC'] else
     'Vessel' if x in ['CapEC', 'ArtEC', 'VenEC', 'Lymphatic', ] else
     'SMC' if x in ['Mural','Pericyte', 'SMC'] else
     'FB' if x in ['FB', 'NerveFB', 'Tenocyte'] else
     'Schwann' if x in ['nmSchwann_cell', 'mSchwann_cell'] else x)

# %%
de_results['celltype_group'].value_counts()
# Out:
# Immune         438022
# Myofiber       370634
# Vessel         134776
# FB             101082
# SMC            101082
# Schwann         67388
# Adipocyte       33694
# MuSC            33694
# Mesothelium     33694
# Name: celltype_group, dtype: int64

# %%
de_results.shape
df_ctype_broad_exprs.shape
# Out:
# (1314066, 13)
# (1314066, 4)

# %%
results_folder = '/nfs/team205/vk8/scripts/cpdb/SKM_cells2nuclei_broad/out/'
#cpdb_genes = pd.read_csv(f"{results_folder}deconvoluted.txt", sep = "\t")
#cpdb_sign_means = pd.read_csv(f"{results_folder}significant_means.txt", sep = "\t")
cpdb_means = pd.read_csv(f"{results_folder}means.txt", sep = "\t")
#cpdb_ints = pd.read_csv(f"{results_folder}relevant_interactions.txt", sep = "\t")

# %% [markdown]
# cpdb_rel_means = cpdb_means.loc[cpdb_means['interacting_pair'].isin(cpdb_ints['interacting_pair'].values), cpdb_ints.columns]

# %%
cpdb_results = pd.melt(cpdb_means, id_vars = ['id_cp_interaction', 'interacting_pair', 'partner_a', 'partner_b',
       'gene_a', 'gene_b', 'secreted', 'receptor_a', 'receptor_b',
       'annotation_strategy', 'is_integrin'], var_name = 'celltype_pair', value_name = 'mean')

# %%
cpdb_results['celltype_a'] = [x.split('|')[0].replace('-old','').replace('-young','') for x in cpdb_results['celltype_pair']]
cpdb_results['celltype_b'] = [x.split('|')[1].replace('-old','').replace('-young','') for x in cpdb_results['celltype_pair']]

# %%
young_ptrn = re.compile("young")
old_ptrn = re.compile("old")

cpdb_results['age_a'] = cpdb_results['celltype_pair'].apply(lambda x: 'young' if len(re.findall(young_ptrn, x.split('|')[0]))>0 else
                                                        'old' if len(re.findall(old_ptrn, x))>0 else 
                                                        'unknown')
cpdb_results['age_b'] = cpdb_results['celltype_pair'].apply(lambda x: 'young' if len(re.findall(young_ptrn, x.split('|')[1]))>0 else
                                                        'old' if len(re.findall(old_ptrn, x))>0 else 
                                                        'unknown')

# %% [markdown]
# cpdb_results['age_a'] = [x.split('|')[0].split('-')[1] for x in cpdb_results['celltype_pair']]
# cpdb_results['age_b'] = [x.split('|')[1].split('-')[1] for x in cpdb_results['celltype_pair']]

# %%
cpdb_results['gene_receptor'] = [g1 if r1 else g2 for g1, g2, r1, r2 in zip(cpdb_results.gene_a, cpdb_results.gene_b, cpdb_results.receptor_a, cpdb_results.receptor_b)]
cpdb_results['gene_ligand'] = [g2 if r1 else g1 for g1, g2, r1, r2 in zip(cpdb_results.gene_a, cpdb_results.gene_b, cpdb_results.receptor_a, cpdb_results.receptor_b)]

cpdb_results['celltype_receptor'] = [g1 if r1 else g2 for g1, g2, r1, r2 in zip(cpdb_results.celltype_a, cpdb_results.celltype_b, cpdb_results.receptor_a, cpdb_results.receptor_b)]
cpdb_results['celltype_ligand'] = [g2 if r1 else g1 for g1, g2, r1, r2 in zip(cpdb_results.celltype_a, cpdb_results.celltype_b, cpdb_results.receptor_a, cpdb_results.receptor_b)]

cpdb_results.drop(columns=['gene_a', 'gene_b', 'celltype_a', 'celltype_b', 'receptor_a', 'receptor_b'], inplace=True)

cpdb_results['gene_receptor_id'] = [f'{x}-rec' for x in cpdb_results.gene_receptor]
cpdb_results['gene_ligand_id'] = [f'{x}-lig' for x in cpdb_results.gene_ligand]

cpdb_results['celltype_receptor_id'] = [f'{x}-rec' for x in cpdb_results.celltype_receptor]
cpdb_results['celltype_ligand_id'] = [f'{x}-lig' for x in cpdb_results.celltype_ligand]

# %%
cpdb_results["celltype_receptor"].value_counts()
# Out:
# MF_typeI                  194916
# B-plasma                  194916
# T-cell                    194916
# MTJ                       194916
# MuSC                      194916
# MF_typeII(cytoplasmic)    194916
# cDC1                      194916
# NMJ                       194916
# Pericyte                  194916
# MF_type-HOOK2+            194916
# Macrophage                194916
# Mesothelium               194916
# Lymphatic                 194916
# cDC2                      194916
# nmSchwann_cell            194916
# Tenocyte                  194916
# Mast_cell                 194916
# Adipocyte                 194916
# MF_type-SORBS2            194916
# NK-cell                   194916
# MF_typeII                 194916
# FB                        194916
# B-cell                    194916
# mSchwann_cell             194916
# MF_typeI(cytoplasmic)     194916
# VenEC                     194916
# Neutrophil                194916
# ArtEC                     194916
# Mural                     194916
# MF_type-MYH8+             194916
# CapEC                     194916
# MF_typeI(fg)              194916
# SMC                       194916
# MF_typeII(fg)             194916
# Monocyte                  194916
# NerveFB                   194916
# Eosinophil                 97458
# pDC                        97458
# Name: celltype_receptor, dtype: int64

# %% [markdown]
# ### Filter out required results

# %%
df = cpdb_results[(cpdb_results['age_a']=='old') & (cpdb_results['age_b']=='old') & \
     (cpdb_results['gene_ligand'].isin(['CCL2', 'CCL3', 'CCL4', 'CXCL8'])) & (cpdb_results['mean']>0)]

# %%
df.shape
# Out:
# (11055, 19)

# %%
de_results
# Out:
#           celltype           gene          ENSEMBL      ltsr  beta_old  \
# 0             MuSC     FO538757.2  ENSG00000279457  0.000052  0.022952
# 1             MuSC     AP006222.2  ENSG00000228463  0.000005 -0.002092
# 2             MuSC   RP5-857K21.4  ENSG00000230021  0.000161  0.020245
# 3             MuSC  RP11-206L10.9  ENSG00000237491  0.000020  0.008438
# 4             MuSC      LINC00115  ENSG00000225880  0.000005 -0.000963
# ...            ...            ...              ...       ...       ...
# 1314061  Adipocyte            NaN  ENSG00000278633       NaN       NaN
# 1314062  Adipocyte            NaN  ENSG00000277856       NaN       NaN
# 1314063  Adipocyte            NaN  ENSG00000275063       NaN       NaN
# 1314064  Adipocyte            NaN  ENSG00000277475       NaN       NaN
# 1314065  Adipocyte            NaN  ENSG00000268674       NaN       NaN
#
#          beta_young  flag5    log2fc   sign REGULATION  mean_young  mean_aged  \
# 0         -0.018559   True  0.041512  False       none    0.149266   0.131244
# 1          0.002806   True -0.004899  False       none    0.070520   0.074098
# 2         -0.020712  False  0.040957  False       none    0.000168   0.000253
# 3         -0.008829  False  0.017268  False       none    0.015160   0.019669
# 4          0.001038  False -0.002001  False       none    0.015503   0.009462
# ...             ...    ...       ...    ...        ...         ...        ...
# 1314061         NaN    NaN       NaN    NaN        NaN    0.000000   0.000000
# 1314062         NaN    NaN       NaN    NaN        NaN    0.000000   0.000000
# 1314063         NaN    NaN       NaN    NaN        NaN    0.000000   0.000000
# 1314064         NaN    NaN       NaN    NaN        NaN    0.000000   0.000000
# 1314065         NaN    NaN       NaN    NaN        NaN    0.000000   0.000000
#
#         celltype_group
# 0                 MuSC
# 1                 MuSC
# 2                 MuSC
# 3                 MuSC
# 4                 MuSC
# ...                ...
# 1314061      Adipocyte
# 1314062      Adipocyte
# 1314063      Adipocyte
# 1314064      Adipocyte
# 1314065      Adipocyte
#
# [1314066 rows x 13 columns]

# %%
df_merged = df.merge(de_results[['celltype', 'gene', 'log2fc', 'REGULATION', 'mean_young', 'mean_aged', \
                                 'celltype_group', 'flag5']], how = 'left', \
                                 left_on = ['celltype_ligand', 'gene_ligand'], right_on = ['celltype', 'gene'])

# %%
df_merged2 = df_merged.merge(de_results[['celltype', 'gene', 'log2fc', 'REGULATION', 'mean_young', 'mean_aged', 'celltype_group', \
                                        'flag5']], how = 'left', \
                       left_on = ['celltype_receptor', 'gene_receptor'],right_on = ['celltype', 'gene'], suffixes = ("-lig", "-rec"))

# %%
df_merged2['mean_rec-lig'] = df_merged2.apply(lambda x: 0 if \
      ((x['mean_aged-lig']==0) | np.isnan(x['mean_aged-lig'])) | \
      ((x['mean_aged-rec']==0) | np.isnan(x['mean_aged-rec'])) else x[['mean_aged-lig', 'mean_aged-rec']].mean(), \
                                        axis = 1)

# %%
df_merged2.to_csv(immune = sc.read(f"{data_folder}/SKM_immune_human_2022-03-30.h5ad")
fb = sc.read(f"{data_folder}/SKM_fibroblasts_Schwann_human_2022-03-30.h5ad")
endo_smc = sc.read(f"{data_folder}/SKM_Endothelium_SMC_human_2022-03-30.h5ad"))

# %%
df_merged2.reset_index(drop = True, inplace = True)

# %% [markdown]
# int_filt = merged2.loc[(merged2['mean']>0.5) & (merged2['REGULATION-lig']=='up')]

# %%
df_plt = df_merged2[['gene_ligand', 'gene_receptor', 'celltype_ligand', 'celltype_group-lig', 'celltype_receptor', \
'celltype_group-rec', 'gene_receptor_id','gene_ligand_id', 'celltype_ligand_id', 'celltype_receptor_id', \
'mean', 'REGULATION-lig', 'REGULATION-rec', 'mean_young-lig', 'mean_aged-lig', \
                  'mean_young-rec', 'mean_aged-rec', 'flag5-lig', 'flag5-rec']].drop_duplicates().reset_index(drop=True)

# %%
df_plt.shape
# Out:
# (11055, 19)

# %%
sum(df_plt['celltype_receptor'].isin(['MF_typeI(fg)', 'MF_typeII(fg)', 'MF_typeI(cytoplasmic)', \
                                                  'MF_typeII(cytoplasmic)']))
# Out:
# 896

# %%
sum(df_plt['celltype_receptor'].isin(['MF_typeI(fg)', 'MF_typeII(fg)', 'MF_typeI(cytoplasmic)', \
                                                  'MF_typeII(cytoplasmic)']))
# Out:
# 896

# %%
df_plt_filt = df_plt[~((df_plt['celltype_ligand'].isin(['MF_typeI(fg)', 'MF_typeII(fg)', 'MF_typeI(cytoplasmic)', \
                                                  'MF_typeII(cytoplasmic)'])) | \
              (df_plt['celltype_receptor'].isin(['MF_typeI(fg)', 'MF_typeII(fg)', 'MF_typeI(cytoplasmic)', \
                                                  'MF_typeII(cytoplasmic)'])))]

# %%
df_plt_filt[df_plt_filt['mean_aged-rec'].isnull()]
# Out:
#       gene_ligand gene_receptor celltype_ligand celltype_group-lig  \
# 29           CCL4        GPRC5D       Adipocyte          Adipocyte
# 54           CCL4        GPRC5D       Adipocyte          Adipocyte
# 57           CCL3          CCR3       Adipocyte          Adipocyte
# 65           CCL4        GPRC5D       Adipocyte          Adipocyte
# 84           CCL4          CCR8       Adipocyte          Adipocyte
# ...           ...           ...             ...                ...
# 10918        CCL3          CCR3             pDC             Immune
# 10969        CCL4        GPRC5D             pDC             Immune
# 10971        CCL3          CCR3             pDC             Immune
# 10999        CCL4          CCR8             pDC             Immune
# 11006        CCL3          CCR3             pDC             Immune
#
#       celltype_receptor celltype_group-rec gene_receptor_id gene_ligand_id  \
# 29             B-plasma                NaN       GPRC5D-rec       CCL4-lig
# 54                   FB                NaN       GPRC5D-rec       CCL4-lig
# 57                   FB                NaN         CCR3-rec       CCL3-lig
# 65            Lymphatic                NaN       GPRC5D-rec       CCL4-lig
# 84       MF_type-SORBS2                NaN         CCR8-rec       CCL4-lig
# ...                 ...                ...              ...            ...
# 10918        Macrophage                NaN         CCR3-rec       CCL3-lig
# 10969               NMJ                NaN       GPRC5D-rec       CCL4-lig
# 10971               NMJ                NaN         CCR3-rec       CCL3-lig
# 10999            T-cell                NaN         CCR8-rec       CCL4-lig
# 11006            T-cell                NaN         CCR3-rec       CCL3-lig
#
#       celltype_ligand_id celltype_receptor_id   mean REGULATION-lig  \
# 29         Adipocyte-lig         B-plasma-rec  0.022           none
# 54         Adipocyte-lig               FB-rec  0.008           none
# 57         Adipocyte-lig               FB-rec  0.011           none
# 65         Adipocyte-lig        Lymphatic-rec  0.010           none
# 84         Adipocyte-lig   MF_type-SORBS2-rec  0.009           none
# ...                  ...                  ...    ...            ...
# 10918            pDC-lig       Macrophage-rec  0.045           none
# 10969            pDC-lig              NMJ-rec  0.101           none
# 10971            pDC-lig              NMJ-rec  0.050           none
# 10999            pDC-lig           T-cell-rec  0.098           none
# 11006            pDC-lig           T-cell-rec  0.045           none
#
#       REGULATION-rec  mean_young-lig  mean_aged-lig  mean_young-rec  \
# 29               NaN             0.0       0.016422             NaN
# 54               NaN             0.0       0.016422             NaN
# 57               NaN             0.0       0.021076             NaN
# 65               NaN             0.0       0.016422             NaN
# 84               NaN             0.0       0.016422             NaN
# ...              ...             ...            ...             ...
# 10918            NaN             0.0       0.090141             NaN
# 10969            NaN             0.0       0.193478             NaN
# 10971            NaN             0.0       0.090141             NaN
# 10999            NaN             0.0       0.193478             NaN
# 11006            NaN             0.0       0.090141             NaN
#
#        mean_aged-rec flag5-lig flag5-rec
# 29               NaN     False       NaN
# 54               NaN     False       NaN
# 57               NaN     False       NaN
# 65               NaN     False       NaN
# 84               NaN     False       NaN
# ...              ...       ...       ...
# 10918            NaN      True       NaN
# 10969            NaN      True       NaN
# 10971            NaN      True       NaN
# 10999            NaN      True       NaN
# 11006            NaN      True       NaN
#
# [578 rows x 19 columns]

# %%
df_plt_filt2 = df_plt_filt.loc[(df_plt_filt['flag5-lig']==True) & (df_plt_filt['flag5-rec']==True)]

# %%
de_results[(de_results['celltype']=='NK-cell') &(de_results['gene']=='CCL4')]
# Out:
#        celltype  gene          ENSEMBL  ltsr  beta_old  beta_young flag5  \
# 275695  NK-cell  CCL4  ENSG00000275302   1.0  0.227593    0.019925  True
#
#           log2fc  sign REGULATION  mean_young  mean_aged celltype_group
# 275695  0.207668  True         up    2.577406   2.809175         Immune

# %%
df_plt_filt2.loc[(df_plt_filt2['celltype_ligand']=='NK-cell')&(df_plt_filt2['gene_ligand']=='CCL4')]
# Out:
#      gene_ligand gene_receptor celltype_ligand celltype_group-lig  \
# 2409        CCL4         ACKR2         NK-cell             Immune
# 6979        CCL4        SLC7A1         NK-cell             Immune
# 6996        CCL4          CNR2         NK-cell             Immune
# 7008        CCL4        SLC7A1         NK-cell             Immune
# 7029        CCL4        SLC7A1         NK-cell             Immune
# 7035        CCL4        SLC7A1         NK-cell             Immune
# 7049        CCL4        SLC7A1         NK-cell             Immune
# 7178        CCL4          CCR5         NK-cell             Immune
# 7192        CCL4        SLC7A1         NK-cell             Immune
# 7227        CCL4        SLC7A1         NK-cell             Immune
# 7297        CCL4        SLC7A1         NK-cell             Immune
# 7309        CCL4        SLC7A1         NK-cell             Immune
# 7317        CCL4          CCR5         NK-cell             Immune
# 7319        CCL4        SLC7A1         NK-cell             Immune
# 7341        CCL4        SLC7A1         NK-cell             Immune
#
#      celltype_receptor celltype_group-rec gene_receptor_id gene_ligand_id  \
# 2409         Lymphatic             Vessel        ACKR2-rec       CCL4-lig
# 6979         Adipocyte          Adipocyte       SLC7A1-rec       CCL4-lig
# 6996            B-cell             Immune         CNR2-rec       CCL4-lig
# 7008          B-plasma             Immune       SLC7A1-rec       CCL4-lig
# 7029        Eosinophil             Immune       SLC7A1-rec       CCL4-lig
# 7035                FB                 FB       SLC7A1-rec       CCL4-lig
# 7049         Lymphatic             Vessel       SLC7A1-rec       CCL4-lig
# 7178          Monocyte             Immune         CCR5-rec       CCL4-lig
# 7192              MuSC               MuSC       SLC7A1-rec       CCL4-lig
# 7227               NMJ           Myofiber       SLC7A1-rec       CCL4-lig
# 7297             VenEC             Vessel       SLC7A1-rec       CCL4-lig
# 7309              cDC1             Immune       SLC7A1-rec       CCL4-lig
# 7317              cDC2             Immune         CCR5-rec       CCL4-lig
# 7319              cDC2             Immune       SLC7A1-rec       CCL4-lig
# 7341               pDC             Immune       SLC7A1-rec       CCL4-lig
#
#      celltype_ligand_id celltype_receptor_id   mean REGULATION-lig  \
# 2409        NK-cell-lig        Lymphatic-rec  1.430             up
# 6979        NK-cell-lig        Adipocyte-rec  1.492             up
# 6996        NK-cell-lig           B-cell-rec  1.459             up
# 7008        NK-cell-lig         B-plasma-rec  1.426             up
# 7029        NK-cell-lig       Eosinophil-rec  1.431             up
# 7035        NK-cell-lig               FB-rec  1.427             up
# 7049        NK-cell-lig        Lymphatic-rec  1.499             up
# 7178        NK-cell-lig         Monocyte-rec  1.423             up
# 7192        NK-cell-lig             MuSC-rec  1.420             up
# 7227        NK-cell-lig              NMJ-rec  1.442             up
# 7297        NK-cell-lig            VenEC-rec  1.451             up
# 7309        NK-cell-lig             cDC1-rec  1.418             up
# 7317        NK-cell-lig             cDC2-rec  1.477             up
# 7319        NK-cell-lig             cDC2-rec  1.428             up
# 7341        NK-cell-lig              pDC-rec  1.551             up
#
#      REGULATION-rec  mean_young-lig  mean_aged-lig  mean_young-rec  \
# 2409           none        2.577406       2.809175        0.169359
# 6979           none        2.577406       2.809175        0.242729
# 6996           none        2.577406       2.809175        0.135127
# 7008           none        2.577406       2.809175        0.208464
# 7029           none        2.577406       2.809175        0.000000
# 7035           none        2.577406       2.809175        0.087477
# 7049           none        2.577406       2.809175        0.278546
# 7178           none        2.577406       2.809175        0.071319
# 7192           none        2.577406       2.809175        0.075719
# 7227           none        2.577406       2.809175        0.102025
# 7297           none        2.577406       2.809175        0.137651
# 7309           none        2.577406       2.809175        0.089717
# 7317           none        2.577406       2.809175        0.197819
# 7319           none        2.577406       2.809175        0.043692
# 7341           none        2.577406       2.809175        0.000000
#
#       mean_aged-rec flag5-lig flag5-rec
# 2409       0.051229      True      True
# 6979       0.175701      True      True
# 6996       0.108010      True      True
# 7008       0.042247      True      True
# 7029       0.051893      True      True
# 7035       0.045341      True      True
# 7049       0.188376      True      True
# 7178       0.037634      True      True
# 7192       0.031276      True      True
# 7227       0.075219      True      True
# 7297       0.092611      True      True
# 7309       0.027603      True      True
# 7317       0.145139      True      True
# 7319       0.047618      True      True
# 7341       0.292557      True      True

# %%
df_plt_filt2
# Out:
#       gene_ligand gene_receptor celltype_ligand celltype_group-lig  \
# 31           CCL2          CCR2       Adipocyte          Adipocyte
# 34           CCL2         CCR10       Adipocyte          Adipocyte
# 41           CCL2         ACKR1       Adipocyte          Adipocyte
# 67           CCL2         ACKR1       Adipocyte          Adipocyte
# 182          CCL2          CCR2       Adipocyte          Adipocyte
# ...           ...           ...             ...                ...
# 11035        CCL4        SLC7A1             pDC             Immune
# 11037        CCL3           IDE             pDC             Immune
# 11039        CCL3          CCR1             pDC             Immune
# 11050        CCL4        SLC7A1             pDC             Immune
# 11051        CCL3           IDE             pDC             Immune
#
#       celltype_receptor celltype_group-rec gene_receptor_id gene_ligand_id  \
# 31             B-plasma             Immune         CCR2-rec       CCL2-lig
# 34             B-plasma             Immune        CCR10-rec       CCL2-lig
# 41                CapEC             Vessel        ACKR1-rec       CCL2-lig
# 67            Lymphatic             Vessel        ACKR1-rec       CCL2-lig
# 182            Monocyte             Immune         CCR2-rec       CCL2-lig
# ...                 ...                ...              ...            ...
# 11035              cDC2             Immune       SLC7A1-rec       CCL4-lig
# 11037              cDC2             Immune          IDE-rec       CCL3-lig
# 11039              cDC2             Immune         CCR1-rec       CCL3-lig
# 11050               pDC             Immune       SLC7A1-rec       CCL4-lig
# 11051               pDC             Immune          IDE-rec       CCL3-lig
#
#       celltype_ligand_id celltype_receptor_id   mean REGULATION-lig  \
# 31         Adipocyte-lig         B-plasma-rec  0.143           none
# 34         Adipocyte-lig         B-plasma-rec  0.154           none
# 41         Adipocyte-lig            CapEC-rec  0.152           none
# 67         Adipocyte-lig        Lymphatic-rec  0.560           none
# 182        Adipocyte-lig         Monocyte-rec  0.084           none
# ...                  ...                  ...    ...            ...
# 11035            pDC-lig             cDC2-rec  0.121           none
# 11037            pDC-lig             cDC2-rec  0.064           none
# 11039            pDC-lig             cDC2-rec  0.138           none
# 11050            pDC-lig              pDC-rec  0.243           none
# 11051            pDC-lig              pDC-rec  0.065           none
#
#       REGULATION-rec  mean_young-lig  mean_aged-lig  mean_young-rec  \
# 31                dw        0.047444       0.115579        0.232737
# 34              none        0.047444       0.115579        0.111929
# 41              none        0.047444       0.115579        0.125103
# 67                up        0.047444       0.115579        0.248413
# 182               dw        0.047444       0.115579        0.108540
# ...              ...             ...            ...             ...
# 11035           none        0.000000       0.193478        0.043692
# 11037           none        0.000000       0.090141        0.072747
# 11039             dw        0.000000       0.090141        0.432870
# 11050           none        0.000000       0.193478        0.000000
# 11051           none        0.000000       0.090141        0.000000
#
#        mean_aged-rec flag5-lig flag5-rec
# 31          0.170574      True      True
# 34          0.191570      True      True
# 41          0.188752      True      True
# 67          1.003917      True      True
# 182         0.052353      True      True
# ...              ...       ...       ...
# 11035       0.047618      True      True
# 11037       0.037869      True      True
# 11039       0.186715      True      True
# 11050       0.292557      True      True
# 11051       0.039737      True      True
#
# [675 rows x 19 columns]

# %%
def graph_elements(st_df, save = ""):
    nodes = pd.concat([
        st_df[['gene_receptor_id', 'gene_receptor']].drop_duplicates().rename(columns={'gene_receptor_id': 'node_id', 'gene_receptor': 'label'}).assign(layer=2, type='gene', type2='gene'),
        st_df[['gene_ligand_id', 'gene_ligand']].drop_duplicates().rename(columns={'gene_ligand_id': 'node_id', 'gene_ligand': 'label'}).assign(layer=3, type='gene', type2='gene'),

        st_df[['celltype_ligand_id', 'celltype_ligand', 'celltype_group-lig']].drop_duplicates().\
        rename(columns={'celltype_ligand_id': 'node_id', 'celltype_ligand': 'label', 'celltype_group-lig': 'group'}).assign(layer=4, type2='celltype'),
        st_df[['celltype_receptor_id', 'celltype_receptor', 'celltype_group-rec']].drop_duplicates().\
        rename(columns={'celltype_receptor_id': 'node_id', 'celltype_receptor': 'label', 'celltype_group-rec': 'group'}).assign(layer=1, type2='celltype'),
    ], axis=0).drop_duplicates().reset_index(drop=True)

    from textwrap import fill

    nodes['label_unwrapped'] = nodes['label']
    #nodes['label'] = [fill(x, 30) for x in nodes['label']]
    print(nodes)
    edges = pd.concat([
    st_df[['gene_ligand_id', 'gene_receptor_id']].drop_duplicates().rename(columns={'gene_ligand_id': 'from', 'gene_receptor_id': 'to'}).assign(type='reclig', regulation = "none", mean = 1),
    st_df[['celltype_ligand_id', 'gene_ligand_id', 'REGULATION-lig', 'mean_aged-lig']].drop_duplicates().rename(columns={'celltype_ligand_id': 'from', 'gene_ligand_id': 'to', 'REGULATION-lig' : 'regulation', 'mean_aged-lig':\
                                                                                     'mean'}),
    st_df[['celltype_receptor_id', 'gene_receptor_id', 'REGULATION-rec', 'mean_aged-rec']].drop_duplicates().rename(columns={'celltype_receptor_id': 'from', 'gene_receptor_id': 'to', 'REGULATION-rec' : 'regulation', 'mean_aged-rec':\
                                                                                     'mean'}),    
    ], axis=0).fillna('')
    print(edges)
    nodes.to_csv(f"{save}/nodes.csv", index=False)
    edges.to_csv(f"{save}/edges.csv", index=False)

# %%
graph_elements(df_plt_filt2.loc[df_plt_filt2['gene_ligand'] == 'CCL2'], \
               save = "/nfs/team205/vk8/processed_data/muscle/data_v3/cpdb_graphs/ccl2_v2")
# Out:
#                node_id           label  layer  type     type2      group  \
# 0             CCR2-rec            CCR2      2  gene      gene        NaN
# 1            CCR10-rec           CCR10      2  gene      gene        NaN
# 2            ACKR1-rec           ACKR1      2  gene      gene        NaN
# 3            ACKR2-rec           ACKR2      2  gene      gene        NaN
# 4             CCL2-lig            CCL2      3  gene      gene        NaN
# 5        Adipocyte-lig       Adipocyte      4   NaN  celltype  Adipocyte
# 6            ArtEC-lig           ArtEC      4   NaN  celltype     Vessel
# 7         B-plasma-lig        B-plasma      4   NaN  celltype     Immune
# 8            CapEC-lig           CapEC      4   NaN  celltype     Vessel
# 9               FB-lig              FB      4   NaN  celltype         FB
# 10       Lymphatic-lig       Lymphatic      4   NaN  celltype     Vessel
# 11   MF_type-MYH8+-lig   MF_type-MYH8+      4   NaN  celltype   Myofiber
# 12      Macrophage-lig      Macrophage      4   NaN  celltype     Immune
# 13       Mast_cell-lig       Mast_cell      4   NaN  celltype     Immune
# 14            MuSC-lig            MuSC      4   NaN  celltype       MuSC
# 15           Mural-lig           Mural      4   NaN  celltype        SMC
# 16         NerveFB-lig         NerveFB      4   NaN  celltype         FB
# 17        Pericyte-lig        Pericyte      4   NaN  celltype        SMC
# 18             SMC-lig             SMC      4   NaN  celltype        SMC
# 19        Tenocyte-lig        Tenocyte      4   NaN  celltype         FB
# 20           VenEC-lig           VenEC      4   NaN  celltype     Vessel
# 21            cDC2-lig            cDC2      4   NaN  celltype     Immune
# 22   mSchwann_cell-lig   mSchwann_cell      4   NaN  celltype    Schwann
# 23  nmSchwann_cell-lig  nmSchwann_cell      4   NaN  celltype    Schwann
# 24        B-plasma-rec        B-plasma      1   NaN  celltype     Immune
# 25           CapEC-rec           CapEC      1   NaN  celltype     Vessel
# 26       Lymphatic-rec       Lymphatic      1   NaN  celltype     Vessel
# 27        Monocyte-rec        Monocyte      1   NaN  celltype     Immune
# 28           Mural-rec           Mural      1   NaN  celltype        SMC
# 29         NerveFB-rec         NerveFB      1   NaN  celltype         FB
# 30        Pericyte-rec        Pericyte      1   NaN  celltype        SMC
# 31             SMC-rec             SMC      1   NaN  celltype        SMC
# 32           VenEC-rec           VenEC      1   NaN  celltype     Vessel
# 33            cDC2-rec            cDC2      1   NaN  celltype     Immune
#
#    label_unwrapped
# 0             CCR2
# 1            CCR10
# 2            ACKR1
# 3            ACKR2
# 4             CCL2
# 5        Adipocyte
# 6            ArtEC
# 7         B-plasma
# 8            CapEC
# 9               FB
# 10       Lymphatic
# 11   MF_type-MYH8+
# 12      Macrophage
# 13       Mast_cell
# 14            MuSC
# 15           Mural
# 16         NerveFB
# 17        Pericyte
# 18             SMC
# 19        Tenocyte
# 20           VenEC
# 21            cDC2
# 22   mSchwann_cell
# 23  nmSchwann_cell
# 24        B-plasma
# 25           CapEC
# 26       Lymphatic
# 27        Monocyte
# 28           Mural
# 29         NerveFB
# 30        Pericyte
# 31             SMC
# 32           VenEC
# 33            cDC2
#                     from         to    type regulation      mean
# 31              CCL2-lig   CCR2-rec  reclig       none  1.000000
# 34              CCL2-lig  CCR10-rec  reclig       none  1.000000
# 41              CCL2-lig  ACKR1-rec  reclig       none  1.000000
# 2167            CCL2-lig  ACKR2-rec  reclig       none  1.000000
# 31         Adipocyte-lig   CCL2-lig               none  0.115579
# 347            ArtEC-lig   CCL2-lig                 up  0.800745
# 985         B-plasma-lig   CCL2-lig               none  0.121788
# 1262           CapEC-lig   CCL2-lig               none  1.036543
# 1826              FB-lig   CCL2-lig                 up  0.825322
# 2196       Lymphatic-lig   CCL2-lig               none  0.312612
# 2254   MF_type-MYH8+-lig   CCL2-lig               none  0.199434
# 2351      Macrophage-lig   CCL2-lig                 up  1.017448
# 2360       Mast_cell-lig   CCL2-lig               none  0.227165
# 2386            MuSC-lig   CCL2-lig                 up  1.047496
# 2395           Mural-lig   CCL2-lig                 up  1.760321
# 2426         NerveFB-lig   CCL2-lig                 up  1.033347
# 2444        Pericyte-lig   CCL2-lig                 up  0.924265
# 2454             SMC-lig   CCL2-lig                 up  1.169246
# 2480        Tenocyte-lig   CCL2-lig               none  0.380068
# 2490           VenEC-lig   CCL2-lig               none  1.963628
# 2514            cDC2-lig   CCL2-lig               none  0.452959
# 2521   mSchwann_cell-lig   CCL2-lig               none  0.718356
# 2522  nmSchwann_cell-lig   CCL2-lig               none  0.585611
# 31          B-plasma-rec   CCR2-rec               none  0.170574
# 34          B-plasma-rec  CCR10-rec               none  0.191570
# 41             CapEC-rec  ACKR1-rec               none  0.188752
# 67         Lymphatic-rec  ACKR1-rec                 up  1.003917
# 182         Monocyte-rec   CCR2-rec               none  0.052353
# 201            Mural-rec  ACKR1-rec               none  0.076040
# 228          NerveFB-rec  CCR10-rec               none  0.150515
# 243         Pericyte-rec  CCR10-rec               none  0.195426
# 251              SMC-rec  CCR10-rec               none  0.100919
# 281            VenEC-rec  ACKR1-rec               none  3.800200
# 300             cDC2-rec   CCR2-rec               none  0.036185
# 2167       Lymphatic-rec  ACKR2-rec               none  0.051229

# %%
graph_elements(df_plt_filt2.loc[df_plt_filt2['gene_ligand'] == 'CCL3'], \
               save = "/nfs/team205/vk8/processed_data/muscle/data_v3/cpdb_graphs/ccl3_v2")
# Out:
#                node_id           label  layer  type     type2      group  \
# 0              IDE-rec             IDE      2  gene      gene        NaN
# 1             CCR1-rec            CCR1      2  gene      gene        NaN
# 2             CCR5-rec            CCR5      2  gene      gene        NaN
# 3            ACKR2-rec           ACKR2      2  gene      gene        NaN
# 4             CCL3-lig            CCL3      3  gene      gene        NaN
# 5         B-plasma-lig        B-plasma      4   NaN  celltype     Immune
# 6       Eosinophil-lig      Eosinophil      4   NaN  celltype     Immune
# 7       Macrophage-lig      Macrophage      4   NaN  celltype     Immune
# 8         Monocyte-lig        Monocyte      4   NaN  celltype     Immune
# 9            Mural-lig           Mural      4   NaN  celltype        SMC
# 10         NK-cell-lig         NK-cell      4   NaN  celltype     Immune
# 11          T-cell-lig          T-cell      4   NaN  celltype     Immune
# 12            cDC1-lig            cDC1      4   NaN  celltype     Immune
# 13            cDC2-lig            cDC2      4   NaN  celltype     Immune
# 14             pDC-lig             pDC      4   NaN  celltype     Immune
# 15       Adipocyte-rec       Adipocyte      1   NaN  celltype  Adipocyte
# 16        B-plasma-rec        B-plasma      1   NaN  celltype     Immune
# 17      Eosinophil-rec      Eosinophil      1   NaN  celltype     Immune
# 18              FB-rec              FB      1   NaN  celltype         FB
# 19  MF_type-HOOK2+-rec  MF_type-HOOK2+      1   NaN  celltype   Myofiber
# 20   MF_type-MYH8+-rec   MF_type-MYH8+      1   NaN  celltype   Myofiber
# 21  MF_type-SORBS2-rec  MF_type-SORBS2      1   NaN  celltype   Myofiber
# 22        MF_typeI-rec        MF_typeI      1   NaN  celltype   Myofiber
# 23       MF_typeII-rec       MF_typeII      1   NaN  celltype   Myofiber
# 24             MTJ-rec             MTJ      1   NaN  celltype   Myofiber
# 25      Macrophage-rec      Macrophage      1   NaN  celltype     Immune
# 26        Monocyte-rec        Monocyte      1   NaN  celltype     Immune
# 27           Mural-rec           Mural      1   NaN  celltype        SMC
# 28             NMJ-rec             NMJ      1   NaN  celltype   Myofiber
# 29      Neutrophil-rec      Neutrophil      1   NaN  celltype     Immune
# 30            cDC2-rec            cDC2      1   NaN  celltype     Immune
# 31             pDC-rec             pDC      1   NaN  celltype     Immune
# 32       Lymphatic-rec       Lymphatic      1   NaN  celltype     Vessel
#
#    label_unwrapped
# 0              IDE
# 1             CCR1
# 2             CCR5
# 3            ACKR2
# 4             CCL3
# 5         B-plasma
# 6       Eosinophil
# 7       Macrophage
# 8         Monocyte
# 9            Mural
# 10         NK-cell
# 11          T-cell
# 12            cDC1
# 13            cDC2
# 14             pDC
# 15       Adipocyte
# 16        B-plasma
# 17      Eosinophil
# 18              FB
# 19  MF_type-HOOK2+
# 20   MF_type-MYH8+
# 21  MF_type-SORBS2
# 22        MF_typeI
# 23       MF_typeII
# 24             MTJ
# 25      Macrophage
# 26        Monocyte
# 27           Mural
# 28             NMJ
# 29      Neutrophil
# 30            cDC2
# 31             pDC
# 32       Lymphatic
#                     from         to    type regulation      mean
# 962             CCL3-lig    IDE-rec  reclig       none  1.000000
# 1093            CCL3-lig   CCR1-rec  reclig       none  1.000000
# 1106            CCL3-lig   CCR5-rec  reclig       none  1.000000
# 2201            CCL3-lig  ACKR2-rec  reclig       none  1.000000
# 962         B-plasma-lig   CCL3-lig               none  0.395942
# 1600      Eosinophil-lig   CCL3-lig               none  0.326859
# 2349      Macrophage-lig   CCL3-lig                 up  1.499834
# 2373        Monocyte-lig   CCL3-lig                 up  1.572975
# 2393           Mural-lig   CCL3-lig               none  0.051842
# 2408         NK-cell-lig   CCL3-lig                 up  1.944533
# 2469          T-cell-lig   CCL3-lig               none  0.225161
# 2498            cDC1-lig   CCL3-lig               none  0.128678
# 2512            cDC2-lig   CCL3-lig               none  1.159817
# 2530             pDC-lig   CCL3-lig               none  0.090141
# 962        Adipocyte-rec    IDE-rec               none  0.242521
# 984         B-plasma-rec    IDE-rec               none  0.030317
# 997       Eosinophil-rec    IDE-rec               none  0.084603
# 1003              FB-rec    IDE-rec               none  0.036676
# 1017  MF_type-HOOK2+-rec    IDE-rec               none  0.097748
# 1020   MF_type-MYH8+-rec    IDE-rec               none  0.076408
# 1028  MF_type-SORBS2-rec    IDE-rec               none  0.137271
# 1052        MF_typeI-rec    IDE-rec               none  0.292112
# 1071       MF_typeII-rec    IDE-rec               none  0.271096
# 1081             MTJ-rec    IDE-rec               none  0.265522
# 1093      Macrophage-rec   CCR1-rec               none  0.332305
# 1106        Monocyte-rec   CCR5-rec               none  0.037634
# 1111        Monocyte-rec   CCR1-rec                 dw  0.222046
# 1125           Mural-rec    IDE-rec               none  0.042261
# 1144             NMJ-rec    IDE-rec               none  0.425799
# 1157      Neutrophil-rec   CCR1-rec               none  0.054829
# 1208            cDC2-rec   CCR5-rec               none  0.145139
# 1211            cDC2-rec    IDE-rec               none  0.037869
# 1213            cDC2-rec   CCR1-rec                 dw  0.186715
# 1225             pDC-rec    IDE-rec               none  0.039737
# 2201       Lymphatic-rec  ACKR2-rec               none  0.051229

# %%
graph_elements(df_plt_filt2.loc[df_plt_filt2['gene_ligand'] == 'CCL4'], \
               save = "/nfs/team205/vk8/processed_data/muscle/data_v3/cpdb_graphs/ccl4_v2")
# Out:
#            node_id       label  layer  type     type2      group  \
# 0       SLC7A1-rec      SLC7A1      2  gene      gene        NaN
# 1         CNR2-rec        CNR2      2  gene      gene        NaN
# 2         CCR5-rec        CCR5      2  gene      gene        NaN
# 3        ACKR2-rec       ACKR2      2  gene      gene        NaN
# 4         CCL4-lig        CCL4      3  gene      gene        NaN
# 5       B-cell-lig      B-cell      4   NaN  celltype     Immune
# 6     B-plasma-lig    B-plasma      4   NaN  celltype     Immune
# 7   Eosinophil-lig  Eosinophil      4   NaN  celltype     Immune
# 8   Macrophage-lig  Macrophage      4   NaN  celltype     Immune
# 9    Mast_cell-lig   Mast_cell      4   NaN  celltype     Immune
# 10    Monocyte-lig    Monocyte      4   NaN  celltype     Immune
# 11     NK-cell-lig     NK-cell      4   NaN  celltype     Immune
# 12      T-cell-lig      T-cell      4   NaN  celltype     Immune
# 13        cDC1-lig        cDC1      4   NaN  celltype     Immune
# 14        cDC2-lig        cDC2      4   NaN  celltype     Immune
# 15         pDC-lig         pDC      4   NaN  celltype     Immune
# 16   Adipocyte-rec   Adipocyte      1   NaN  celltype  Adipocyte
# 17      B-cell-rec      B-cell      1   NaN  celltype     Immune
# 18    B-plasma-rec    B-plasma      1   NaN  celltype     Immune
# 19  Eosinophil-rec  Eosinophil      1   NaN  celltype     Immune
# 20          FB-rec          FB      1   NaN  celltype         FB
# 21   Lymphatic-rec   Lymphatic      1   NaN  celltype     Vessel
# 22    Monocyte-rec    Monocyte      1   NaN  celltype     Immune
# 23        MuSC-rec        MuSC      1   NaN  celltype       MuSC
# 24         NMJ-rec         NMJ      1   NaN  celltype   Myofiber
# 25       VenEC-rec       VenEC      1   NaN  celltype     Vessel
# 26        cDC1-rec        cDC1      1   NaN  celltype     Immune
# 27        cDC2-rec        cDC2      1   NaN  celltype     Immune
# 28         pDC-rec         pDC      1   NaN  celltype     Immune
#
#    label_unwrapped
# 0           SLC7A1
# 1             CNR2
# 2             CCR5
# 3            ACKR2
# 4             CCL4
# 5           B-cell
# 6         B-plasma
# 7       Eosinophil
# 8       Macrophage
# 9        Mast_cell
# 10        Monocyte
# 11         NK-cell
# 12          T-cell
# 13            cDC1
# 14            cDC2
# 15             pDC
# 16       Adipocyte
# 17          B-cell
# 18        B-plasma
# 19      Eosinophil
# 20              FB
# 21       Lymphatic
# 22        Monocyte
# 23            MuSC
# 24             NMJ
# 25           VenEC
# 26            cDC1
# 27            cDC2
# 28             pDC
#                 from          to    type regulation      mean
# 591         CCL4-lig  SLC7A1-rec  reclig       none  1.000000
# 608         CCL4-lig    CNR2-rec  reclig       none  1.000000
# 790         CCL4-lig    CCR5-rec  reclig       none  1.000000
# 2188        CCL4-lig   ACKR2-rec  reclig       none  1.000000
# 591       B-cell-lig    CCL4-lig               none  0.115248
# 961     B-plasma-lig    CCL4-lig                 dw  0.196292
# 1599  Eosinophil-lig    CCL4-lig               none  0.359476
# 2350  Macrophage-lig    CCL4-lig                 up  1.464203
# 2359   Mast_cell-lig    CCL4-lig                 up  0.673933
# 2374    Monocyte-lig    CCL4-lig                 up  1.431414
# 2409     NK-cell-lig    CCL4-lig                 up  2.809175
# 2470      T-cell-lig    CCL4-lig               none  0.797211
# 2499        cDC1-lig    CCL4-lig               none  0.071663
# 2513        cDC2-lig    CCL4-lig               none  0.816305
# 2531         pDC-lig    CCL4-lig               none  0.193478
# 591    Adipocyte-rec  SLC7A1-rec               none  0.175701
# 608       B-cell-rec    CNR2-rec               none  0.108010
# 620     B-plasma-rec  SLC7A1-rec               none  0.042247
# 641   Eosinophil-rec  SLC7A1-rec               none  0.051893
# 647           FB-rec  SLC7A1-rec               none  0.045341
# 661    Lymphatic-rec  SLC7A1-rec               none  0.188376
# 790     Monocyte-rec    CCR5-rec               none  0.037634
# 804         MuSC-rec  SLC7A1-rec               none  0.031276
# 839          NMJ-rec  SLC7A1-rec               none  0.075219
# 909        VenEC-rec  SLC7A1-rec               none  0.092611
# 921         cDC1-rec  SLC7A1-rec               none  0.027603
# 929         cDC2-rec    CCR5-rec               none  0.145139
# 931         cDC2-rec  SLC7A1-rec               none  0.047618
# 953          pDC-rec  SLC7A1-rec               none  0.292557
# 2188   Lymphatic-rec   ACKR2-rec               none  0.051229

# %%
graph_elements(df_plt_filt2.loc[df_plt_filt2['gene_ligand'] == 'CXCL8'], \
               save = "/nfs/team205/vk8/processed_data/muscle/data_v3/cpdb_graphs/cxcl8_v2")
# Out:
#             node_id        label  layer  type     type2        group  \
# 0         ACKR1-rec        ACKR1      2  gene      gene          NaN
# 1         CXCR1-rec        CXCR1      2  gene      gene          NaN
# 2         CXCR2-rec        CXCR2      2  gene      gene          NaN
# 3         CXCL8-lig        CXCL8      3  gene      gene          NaN
# 4      B-plasma-lig     B-plasma      4   NaN  celltype       Immune
# 5         CapEC-lig        CapEC      4   NaN  celltype       Vessel
# 6    Eosinophil-lig   Eosinophil      4   NaN  celltype       Immune
# 7    Macrophage-lig   Macrophage      4   NaN  celltype       Immune
# 8   Mesothelium-lig  Mesothelium      4   NaN  celltype  Mesothelium
# 9      Monocyte-lig     Monocyte      4   NaN  celltype       Immune
# 10        Mural-lig        Mural      4   NaN  celltype          SMC
# 11   Neutrophil-lig   Neutrophil      4   NaN  celltype       Immune
# 12        VenEC-lig        VenEC      4   NaN  celltype       Vessel
# 13         cDC1-lig         cDC1      4   NaN  celltype       Immune
# 14         cDC2-lig         cDC2      4   NaN  celltype       Immune
# 15          pDC-lig          pDC      4   NaN  celltype       Immune
# 16        CapEC-rec        CapEC      1   NaN  celltype       Vessel
# 17    Lymphatic-rec    Lymphatic      1   NaN  celltype       Vessel
# 18        Mural-rec        Mural      1   NaN  celltype          SMC
# 19   Neutrophil-rec   Neutrophil      1   NaN  celltype       Immune
# 20        VenEC-rec        VenEC      1   NaN  celltype       Vessel
#
#    label_unwrapped
# 0            ACKR1
# 1            CXCR1
# 2            CXCR2
# 3            CXCL8
# 4         B-plasma
# 5            CapEC
# 6       Eosinophil
# 7       Macrophage
# 8      Mesothelium
# 9         Monocyte
# 10           Mural
# 11      Neutrophil
# 12           VenEC
# 13            cDC1
# 14            cDC2
# 15             pDC
# 16           CapEC
# 17       Lymphatic
# 18           Mural
# 19      Neutrophil
# 20           VenEC
#                   from         to    type regulation      mean
# 994          CXCL8-lig  ACKR1-rec  reclig       none  1.000000
# 1158         CXCL8-lig  CXCR1-rec  reclig       none  1.000000
# 1159         CXCL8-lig  CXCR2-rec  reclig       none  1.000000
# 994       B-plasma-lig  CXCL8-lig               none  0.156601
# 1274         CapEC-lig  CXCL8-lig               none  0.096490
# 1623    Eosinophil-lig  CXCL8-lig               none  0.933039
# 5364    Macrophage-lig  CXCL8-lig                 up  1.652182
# 5970   Mesothelium-lig  CXCL8-lig               none  0.271367
# 6106      Monocyte-lig  CXCL8-lig               none  2.810637
# 6744         Mural-lig  CXCL8-lig               none  0.524341
# 7826    Neutrophil-lig  CXCL8-lig                 dw  2.256114
# 9380         VenEC-lig  CXCL8-lig               none  0.316770
# 9738          cDC1-lig  CXCL8-lig                 up  1.182171
# 10018         cDC2-lig  CXCL8-lig                 up  2.473203
# 10820          pDC-lig  CXCL8-lig               none  0.052650
# 994          CapEC-rec  ACKR1-rec               none  0.188752
# 1015     Lymphatic-rec  ACKR1-rec                 up  1.003917
# 1128         Mural-rec  ACKR1-rec               none  0.076040
# 1158    Neutrophil-rec  CXCR1-rec               none  0.338803
# 1159    Neutrophil-rec  CXCR2-rec                 dw  0.250249
# 1198         VenEC-rec  ACKR1-rec               none  3.800200

# %%
edges = pd.concat([
    df[['gene_ligand_id', 'gene_receptor_id', 'mean']].drop_duplicates().rename(columns={'gene_ligand_id': 'from', 'gene_receptor_id': 'to'}).assign(type='reclig'),
    df[['celltype_ligand_id', 'gene_ligand_id']].drop_duplicates().rename(columns={'celltype_ligand_id': 'from', 'gene_ligand_id': 'to'}),
    df[['celltype_receptor_id', 'gene_receptor_id']].drop_duplicates().rename(columns={'celltype_receptor_id': 'from', 'gene_receptor_id': 'to'}),    
], axis=0).fillna('')

edges
# Out:
#                     from         to   mean    type
# 0               CCL2-lig  ACKR2-rec   1.31  reclig
# 1               CCL2-lig  ACKR2-rec  1.311  reclig
# 2               CCL2-lig  ACKR2-rec  1.936  reclig
# 3               CCL2-lig  ACKR1-rec  0.915  reclig
# 4               CCL3-lig  ACKR2-rec  4.092  reclig
# ...                  ...        ...    ...     ...
# 1188             SMC-rec  ACKR2-rec
# 1267        Tenocyte-rec  ACKR2-rec
# 1347           VenEC-rec  ACKR2-rec
# 1474            cDC2-rec  ACKR2-rec
# 1728  nmSchwann_cell-rec  ACKR2-rec
#
# [1394 rows x 4 columns]

# %%
nodes.to_csv("/nfs/team205/vk8/processed_data/muscle/data_v3/cpdb_graphs/nodes.csv", index=False)

# %%
edges.to_csv("/nfs/team205/vk8/processed_data/muscle/data_v3/cpdb_graphs/edges.csv", index=False)
